# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import keras
import numpy as np

# %%
mnist = keras.datasets.mnist
(train_features,train_labels),(test_features,test_labels)=mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
train_features.shape
# Out:
# (60000, 28, 28)

# %%
test_features.shape
# Out:
# (10000, 28, 28)

# %%
idx=100
img=train_features[idx]
print(train_labels[idx])
# Out:
# 5

# %%
plt.gray()
plt.imshow(img)

# %%
np.min(img),np.max(img)
# Out:
# (np.uint8(0), np.uint8(255))

# %%
train_features=train_features/255.0
test_features=test_features/255.0

# %%
model=keras.Sequential()
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(units=128,activation='relu'))
model.add(keras.layers.Dense(units=128,activation='relu'))
model.add(keras.layers.Dense(units=10,activation=keras.activations.softmax))

# %%
model.compile(optimizer='adam',
              loss=keras.losses.sparse_categorical_crossentropy,
              metrics=['Accuracy'])

# %%
hist=model.fit(train_features,train_labels,epochs=40,batch_size=256,validation_data=(test_features,test_labels))
# Out:
# Epoch 1/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - Accuracy: 0.7984 - loss: 0.7357 - val_Accuracy: 0.9501 - val_loss: 0.1750
# Epoch 2/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9542 - loss: 0.1573 - val_Accuracy: 0.9633 - val_loss: 0.1183
# Epoch 3/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9678 - loss: 0.1068 - val_Accuracy: 0.9671 - val_loss: 0.1033
# Epoch 4/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Accuracy: 0.9768 - loss: 0.0813 - val_Accuracy: 0.9729 - val_loss: 0.0888
# Epoch 5/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Accuracy: 0.9815 - loss: 0.0614 - val_Accuracy: 0.9755 - val_loss: 0.0803
# Epoch 6/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Accuracy: 0.9849 - loss: 0.0493 - val_Accuracy: 0.9765 - val_loss: 0.0760
# Epoch 7/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9882 - loss: 0.0401 - val_Accuracy: 0.9777 - val_loss: 0.0706
# Epoch 8/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9898 - loss: 0.0338 - val_Accuracy: 0.9774 - val_loss: 0.0717
# Epoch 9/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9925 - loss: 0.0265 - val_Accuracy: 0.9777 - val_loss: 0.0729
# Epoch 10/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9940 - loss: 0.0214 - val_Accuracy: 0.9788 - val_loss: 0.0749
# Epoch 11/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9937 - loss: 0.0204 - val_Accuracy: 0.9791 - val_loss: 0.0736
# Epoch 12/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9949 - loss: 0.0169 - val_Accuracy: 0.9785 - val_loss: 0.0800
# Epoch 13/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9969 - loss: 0.0131 - val_Accuracy: 0.9756 - val_loss: 0.0851
# Epoch 14/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9979 - loss: 0.0092 - val_Accuracy: 0.9769 - val_loss: 0.0845
# Epoch 15/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9971 - loss: 0.0109 - val_Accuracy: 0.9782 - val_loss: 0.0797
# Epoch 16/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9980 - loss: 0.0079 - val_Accuracy: 0.9781 - val_loss: 0.0860
# Epoch 17/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9978 - loss: 0.0080 - val_Accuracy: 0.9778 - val_loss: 0.0874
# Epoch 18/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9987 - loss: 0.0057 - val_Accuracy: 0.9781 - val_loss: 0.0869
# Epoch 19/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9981 - loss: 0.0066 - val_Accuracy: 0.9770 - val_loss: 0.0886
# Epoch 20/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Accuracy: 0.9969 - loss: 0.0090 - val_Accuracy: 0.9739 - val_loss: 0.1100
# Epoch 21/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Accuracy: 0.9965 - loss: 0.0104 - val_Accuracy: 0.9786 - val_loss: 0.0924
# Epoch 22/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9982 - loss: 0.0062 - val_Accuracy: 0.9780 - val_loss: 0.0963
# Epoch 23/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9992 - loss: 0.0033 - val_Accuracy: 0.9781 - val_loss: 0.0947
# Epoch 24/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9994 - loss: 0.0024 - val_Accuracy: 0.9794 - val_loss: 0.0968
# Epoch 25/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9977 - loss: 0.0072 - val_Accuracy: 0.9763 - val_loss: 0.1124
# Epoch 26/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9973 - loss: 0.0076 - val_Accuracy: 0.9770 - val_loss: 0.1049
# Epoch 27/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9984 - loss: 0.0054 - val_Accuracy: 0.9771 - val_loss: 0.1137
# Epoch 28/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9993 - loss: 0.0026 - val_Accuracy: 0.9777 - val_loss: 0.1030
# Epoch 29/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9991 - loss: 0.0033 - val_Accuracy: 0.9778 - val_loss: 0.1053
# Epoch 30/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9999 - loss: 0.0012 - val_Accuracy: 0.9790 - val_loss: 0.0992
# Epoch 31/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 1.0000 - loss: 3.7342e-04 - val_Accuracy: 0.9796 - val_loss: 0.0980
# Epoch 32/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 1.0000 - loss: 1.9556e-04 - val_Accuracy: 0.9795 - val_loss: 0.0993
# Epoch 33/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 1.0000 - loss: 1.6039e-04 - val_Accuracy: 0.9795 - val_loss: 0.1008
# Epoch 34/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 1.0000 - loss: 1.5814e-04 - val_Accuracy: 0.9797 - val_loss: 0.1005
# Epoch 35/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 1.0000 - loss: 1.3248e-04 - val_Accuracy: 0.9798 - val_loss: 0.1009
# Epoch 36/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Accuracy: 1.0000 - loss: 1.2745e-04 - val_Accuracy: 0.9797 - val_loss: 0.1025
# Epoch 37/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Accuracy: 1.0000 - loss: 1.0431e-04 - val_Accuracy: 0.9800 - val_loss: 0.1028
# Epoch 38/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 1.0000 - loss: 9.0599e-05 - val_Accuracy: 0.9803 - val_loss: 0.1034
# Epoch 39/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 1.0000 - loss: 9.7558e-05 - val_Accuracy: 0.9799 - val_loss: 0.1047
# Epoch 40/40
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 1.0000 - loss: 7.8857e-05 - val_Accuracy: 0.9805 - val_loss: 0.1051

# %%
pred=model.predict(test_features)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
plt.figure(figsize=(14,4), facecolor='lightgray')
plt.plot(hist.history['loss'], label='Train Loss')
plt.plot(hist.history['val_loss'], label='Validation Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,4), facecolor='lightgray')
plt.plot(hist.history['Accuracy'], label='Train Accuracy')
plt.plot(hist.history['val_Accuracy'], label='Validation Accuracy')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
for i in range(12):
    plt.subplot(3,4,i+1)
    plt.imshow(test_features[i], cmap='gray')
    plt.title(f"Label: {test_labels[i]}\nPred: {np.argmax(pred[i])}")
    plt.axis('off')

plt.suptitle("Real Labels vs Model Predictions", fontsize=16)
plt.tight_layout()
plt.show()

# %%
pred_classes = np.argmax(pred, axis=1)
plt.figure(figsize=(12,5))
plt.scatter(range(len(test_labels)), test_labels, label="Real Labels", s=10)
plt.scatter(range(len(pred_classes)), pred_classes, label="Predicted Labels", s=10)
plt.xlabel("Sample Index")
plt.ylabel("Digit")
plt.title("Comparison of Real vs Predicted Values")
plt.legend()
plt.show()

# %%
pred_classes = np.argmax(pred, axis=1)
errors = pred_classes != test_labels
plt.figure(figsize=(12,5))
plt.scatter(range(len(test_labels)), test_labels, label="Real Label", s=10)
plt.scatter(np.where(errors)[0], pred_classes[errors], label="Predicted (Wrong)", c="red", s=10)
plt.title("Model Mistakes Highlighted")
plt.xlabel("Sample Index")
plt.ylabel("Digit")
plt.legend()
plt.show()
